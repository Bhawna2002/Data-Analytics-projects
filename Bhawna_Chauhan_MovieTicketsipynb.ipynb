# %% [markdown]
# #MovieTickets_1.1

# %% [markdown]
# ***Task 1: Import the pandas library and create a blank dataframe.***

# %%
import pandas as pd
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ***Task 2: Add a column named “MovieName” to the table with the below movie names.***

# %%
df["MovieName"]=["Shaitaan","Dune","Fighter","Fall Guy","Bramayugam","Abigail","Laapataa Ladies","Article 370","Kung Fu Panda 4"]
df
# Out:
#          MovieName
# 0         Shaitaan
# 1             Dune
# 2          Fighter
# 3         Fall Guy
# 4       Bramayugam
# 5          Abigail
# 6  Laapataa Ladies
# 7      Article 370
# 8  Kung Fu Panda 4

# %% [markdown]
# ***Task 3: In the above table add one more column named “Week1TicketsBooked” with the below numbers. ***

# %%
df["Week1TicketsBooked"]=[5600,4000,2500,3500,2500,5000,3600,1900,4900]
df
# Out:
#          MovieName  Week1TicketsBooked
# 0         Shaitaan                5600
# 1             Dune                4000
# 2          Fighter                2500
# 3         Fall Guy                3500
# 4       Bramayugam                2500
# 5          Abigail                5000
# 6  Laapataa Ladies                3600
# 7      Article 370                1900
# 8  Kung Fu Panda 4                4900

# %% [markdown]
# ***Task 4: In the above table add one more column named “Week2TicketsBooked” with the below numbers.***

# %%
df["Week2TicketsBooked"]=[4900,4500,2000,3500,3500,4000,4200,1500,5200]
df
# Out:
#          MovieName  Week1TicketsBooked  Week2TicketsBooked
# 0         Shaitaan                5600                4900
# 1             Dune                4000                4500
# 2          Fighter                2500                2000
# 3         Fall Guy                3500                3500
# 4       Bramayugam                2500                3500
# 5          Abigail                5000                4000
# 6  Laapataa Ladies                3600                4200
# 7      Article 370                1900                1500
# 8  Kung Fu Panda 4                4900                5200

# %% [markdown]
# ***Task 5: In the above table add one more column named “Week3TicketsBooked” with the below numbers.***

# %%
df["Week3TicketsBooked"]=[4000,3500,500,2000,2500,3000,2600,1000,4500]
df
# Out:
#          MovieName  Week1TicketsBooked  Week2TicketsBooked  Week3TicketsBooked
# 0         Shaitaan                5600                4900                4000
# 1             Dune                4000                4500                3500
# 2          Fighter                2500                2000                 500
# 3         Fall Guy                3500                3500                2000
# 4       Bramayugam                2500                3500                2500
# 5          Abigail                5000                4000                3000
# 6  Laapataa Ladies                3600                4200                2600
# 7      Article 370                1900                1500                1000
# 8  Kung Fu Panda 4                4900                5200                4500

# %% [markdown]
# #MovieTickets_1.2

# %% [markdown]
# ***Task 1: In the above table add a column named “TotalTicketsBooked” with the below price.***

# %%
df["TotalTicketsBooked"]=df["Week1TicketsBooked"]+df["Week2TicketsBooked"]+df["Week3TicketsBooked"]
df
# Out:
#          MovieName  Week1TicketsBooked  Week2TicketsBooked  \
# 0         Shaitaan                5600                4900
# 1             Dune                4000                4500
# 2          Fighter                2500                2000
# 3         Fall Guy                3500                3500
# 4       Bramayugam                2500                3500
# 5          Abigail                5000                4000
# 6  Laapataa Ladies                3600                4200
# 7      Article 370                1900                1500
# 8  Kung Fu Panda 4                4900                5200
#
#    Week3TicketsBooked  TotalTicketsBooked
# 0                4000               14500
# 1                3500               12000
# 2                 500                5000
# 3                2000                9000
# 4                2500                8500
# 5                3000               12000
# 6                2600               10400
# ...

# %% [markdown]
# ***Task 2: In the above table add a column named “Week1Percent” by calculating Week1TicketsBooked as percentage of TotalTicketsBooked.***
#
# Where, Week1Percent= Week1TicketsBooked / TotalTicketsBooked * 100

# %%
df["Week1Percent"]=df["Week1TicketsBooked"]/df["TotalTicketsBooked"]*100
df
# Out:
#          MovieName  Week1TicketsBooked  Week2TicketsBooked  \
# 0         Shaitaan                5600                4900
# 1             Dune                4000                4500
# 2          Fighter                2500                2000
# 3         Fall Guy                3500                3500
# 4       Bramayugam                2500                3500
# 5          Abigail                5000                4000
# 6  Laapataa Ladies                3600                4200
# 7      Article 370                1900                1500
# 8  Kung Fu Panda 4                4900                5200
#
#    Week3TicketsBooked  TotalTicketsBooked  Week1Percent
# 0                4000               14500     38.620690
# 1                3500               12000     33.333333
# 2                 500                5000     50.000000
# 3                2000                9000     38.888889
# 4                2500                8500     29.411765
# ...

# %% [markdown]
# ***Task 3: In the above table add a column named “Week2Percent” by calculating Week2TicketsBooked as percentage of TotalTicketsBooked.***
# Where, Week2Percent= Week2TicketsBooked / TotalTicketsBooked * 100

# %%
df["Week2Percent"]=df["Week2TicketsBooked"]/df["TotalTicketsBooked"]*100
df
# Out:
#          MovieName  Week1TicketsBooked  Week2TicketsBooked  \
# 0         Shaitaan                5600                4900
# 1             Dune                4000                4500
# 2          Fighter                2500                2000
# 3         Fall Guy                3500                3500
# 4       Bramayugam                2500                3500
# 5          Abigail                5000                4000
# 6  Laapataa Ladies                3600                4200
# 7      Article 370                1900                1500
# 8  Kung Fu Panda 4                4900                5200
#
#    Week3TicketsBooked  TotalTicketsBooked  Week1Percent  Week2Percent
# 0                4000               14500     38.620690     33.793103
# 1                3500               12000     33.333333     37.500000
# 2                 500                5000     50.000000     40.000000
# 3                2000                9000     38.888889     38.888889
# ...

# %% [markdown]
# ***Task 4: In the above table add a column named “Week3Percent” by calculating Week3TicketsBooked as percentage of TotalTicketsBooked.***
# Where, Week3Percent= Week3TicketsBooked / TotalTicketsBooked * 100

# %%
df["Week3Percent"]=df["Week3TicketsBooked"]/df["TotalTicketsBooked"]*100
df
# Out:
#          MovieName  Week1TicketsBooked  Week2TicketsBooked  \
# 0         Shaitaan                5600                4900
# 1             Dune                4000                4500
# 2          Fighter                2500                2000
# 3         Fall Guy                3500                3500
# 4       Bramayugam                2500                3500
# 5          Abigail                5000                4000
# 6  Laapataa Ladies                3600                4200
# 7      Article 370                1900                1500
# 8  Kung Fu Panda 4                4900                5200
#
#    Week3TicketsBooked  TotalTicketsBooked  Week1Percent  Week2Percent  \
# 0                4000               14500     38.620690     33.793103
# 1                3500               12000     33.333333     37.500000
# 2                 500                5000     50.000000     40.000000
# 3                2000                9000     38.888889     38.888889
# ...

# %% [markdown]
# ***Task 5: In the above table add a column named “TotalCollection” by calculating Total Collection.***
# Where, TotalCollection= TotalTicketsBooked * 250

# %%
df["TotalCollection"]=df["TotalTicketsBooked"]*250
df
# Out:
#          MovieName  Week1TicketsBooked  Week2TicketsBooked  \
# 0         Shaitaan                5600                4900
# 1             Dune                4000                4500
# 2          Fighter                2500                2000
# 3         Fall Guy                3500                3500
# 4       Bramayugam                2500                3500
# 5          Abigail                5000                4000
# 6  Laapataa Ladies                3600                4200
# 7      Article 370                1900                1500
# 8  Kung Fu Panda 4                4900                5200
#
#    Week3TicketsBooked  TotalTicketsBooked  Week1Percent  Week2Percent  \
# 0                4000               14500     38.620690     33.793103
# 1                3500               12000     33.333333     37.500000
# 2                 500                5000     50.000000     40.000000
# 3                2000                9000     38.888889     38.888889
# ...

# %% [markdown]
# #MovieTickets_1.3

# %% [markdown]
# ***Task 1: Find the sum of Week3TicketsBooked.***

# %%
df['Week3TicketsBooked'].sum()
# Out:
# 23600

# %% [markdown]
# ***Task 2: Find the average of Week1TicketsBooked.***

# %%
df["Week1TicketsBooked"].mean()
# Out:
# 3722.222222222222

# %% [markdown]
# ***Task 3: Find the maximum of Week2TicketsBooked.***

# %%
df["Week2TicketsBooked"].max()
# Out:
# 5200

# %% [markdown]
# ***Task 4: Find the total number of Movies.***

# %%
df["MovieName"].count()
# Out:
# 9

# %% [markdown]
# ***Task 5: Find the average of TotalTicketsBooked.***

# %%
df["TotalTicketsBooked"].mean()
# Out:
# 10044.444444444445

# %% [markdown]
# ***Task 6: Find the average of Week3Percent.***

# %%
df["Week3Percent"].mean()
# Out:
# 24.65956122520165

# %% [markdown]
# ***Task 7: Find the sum of TotalCollections of all movies.***

# %%
df["TotalCollection"].sum()
# Out:
# 22600000

# %% [markdown]
# ***Task 8: Find the minimum TotalCollections among all movies.***

# %%
df["TotalCollection"].min()
# Out:
# 1100000

# %% [markdown]
# ***Task 9: Find the average TotalCollections among all movies.***

# %%
df["TotalCollection"].mean()
# Out:
# 2511111.111111111

# %% [markdown]
# ***Task 10: Find the maximum TotalCollections among all movies.***

# %%
df["TotalCollection"].max()
# Out:
# 3650000
